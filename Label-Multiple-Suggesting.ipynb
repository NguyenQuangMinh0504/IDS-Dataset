# %%
import pandas as pd

# %%
dataset = pd.read_csv("./capture_multiple.pcap_Flow.csv")
dataset
# Out:
#                                           Flow ID           Src IP  Src Port  \
# 0            36.22.189.214-10.128.0.42-43608-22-6    36.22.189.214     43608
# 1        162.216.150.214-10.128.0.42-56427-2441-6  162.216.150.214     56427
# 2        162.216.150.134-10.128.0.42-51019-8069-6  162.216.150.134     51019
# 3           61.227.166.186-10.128.0.42-42758-23-6   61.227.166.186     42758
# 4       162.142.125.190-10.128.0.42-63527-12153-6  162.142.125.190     63527
# ...                                           ...              ...       ...
# 531783       222.254.21.74-10.128.0.42-37984-22-6    222.254.21.74     37984
# 531784       10.128.0.42-222.254.21.74-22-52060-6      10.128.0.42        22
# 531785    35.203.211.29-10.128.0.42-57189-46194-6    35.203.211.29     57189
# 531786    89.248.163.208-10.128.0.42-56298-7234-6   89.248.163.208     56298
# 531787         74.48.5.252-10.128.0.42-34800-22-6      74.48.5.252     34800
#
# ...

# %%
attack_ip = ["34.105.126.61", "35.228.215.90", "35.197.230.23", "34.155.133.57"]

# %%
dataset[dataset["Src IP"].isin(attack_ip)]
# Out:
#                                       Flow ID         Src IP  Src Port  \
# 66      34.105.126.61-10.128.0.42-53318-443-6  34.105.126.61     53318
# 67      35.228.215.90-10.128.0.42-36598-443-6  35.228.215.90     36598
# 71      35.197.230.23-10.128.0.42-54412-443-6  35.197.230.23     54412
# 72      34.105.126.61-10.128.0.42-53932-443-6  34.105.126.61     53932
# 73      34.105.126.61-10.128.0.42-53562-443-6  34.105.126.61     53562
# ...                                       ...            ...       ...
# 531241  34.155.133.57-10.128.0.42-43992-443-6  34.155.133.57     43992
# 531242  34.155.133.57-10.128.0.42-43542-443-6  34.155.133.57     43542
# 531243  34.155.133.57-10.128.0.42-43618-443-6  34.155.133.57     43618
# 531244  34.155.133.57-10.128.0.42-51624-443-6  34.155.133.57     51624
# 531245  34.155.133.57-10.128.0.42-43916-443-6  34.155.133.57     43916
#
#              Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
dataset[dataset["Dst IP"].isin(attack_ip)]
# Out:
#                                       Flow ID       Src IP  Src Port  \
# 146     10.128.0.42-35.197.230.23-443-54602-6  10.128.0.42       443
# 196     10.128.0.42-35.197.230.23-443-54584-6  10.128.0.42       443
# 204     10.128.0.42-35.197.230.23-443-54928-6  10.128.0.42       443
# 210     10.128.0.42-35.197.230.23-443-54576-6  10.128.0.42       443
# 212     10.128.0.42-35.197.230.23-443-55182-6  10.128.0.42       443
# ...                                       ...          ...       ...
# 531735  10.128.0.42-34.155.133.57-443-44270-6  10.128.0.42       443
# 531737  10.128.0.42-35.197.230.23-443-34104-6  10.128.0.42       443
# 531742  10.128.0.42-34.155.133.57-443-44176-6  10.128.0.42       443
# 531743  10.128.0.42-35.228.215.90-443-51384-6  10.128.0.42       443
# 531754  10.128.0.42-35.197.230.23-443-34140-6  10.128.0.42       443
#
#                Dst IP  Dst Port  Protocol               Timestamp  \
# 146     35.197.230.23     54602         6  17/12/2023 02:30:01 PM
# ...

# %%
# Suggest labeling
dataset["Label"] = "Normal"
dataset.loc[dataset["Src IP"].isin(attack_ip), "Label"] = "Malicious"
dataset.loc[dataset["Dst IP"].isin(attack_ip), "Label"] = "Malicious"
dataset["Label"].value_counts()
# Out:
# Malicious    530521
# Normal         1267
# Name: Label, dtype: int64
